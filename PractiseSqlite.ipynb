# %%
import sqlite3
import pandas as pd
conn=sqlite3.connect(r"C:\Users\Dell\Desktop\Internship\Practisedb.db")

# %%
df_emp = pd.read_sql_query("Select * from EmpSample ",conn)
df_emp
# Out:
#    Emp_Id Emp_FirstName Emp_City   Emp_State  Emp_Salary    Emp_Address  \
# 0       1        sakshi   Indore         M.P      700000   Hi-Link City
# 1       2        Aditya   Indore         M.P      900000   Bada Ganpati
# 2       3        Simran   Indore         M.P      500000    Kusum Nagar
# 3       4         Pooja   Ratlam         M.P      100000  Chandan Nagar
# 4       5       Kritika   Sedhwa         M.P      300000        Rajwada
# 5       6        piyush     Pune  Maharastra      200000   Chandni Chok
# 6       7         Sahil     Pune  Maharastra      400000      Ratan Bag
# 7       8         Paras     Pune  Maharastra      700000      Dipalpuri
# 8       9         Seema     Pune  Maharastra      800000       malanpur
# 9      10         Radha     Pune  Maharastra      900000            huj
#
#   Emp_LastName     Emp_Email  Emp_Bonus Emp_Dept  Emp_MobileNo
# 0       Shukla   S@gmail.com       5000       CS    8839190162
# ...

# %%
def myfun(s):
    if s.Emp_Salary > 500000:
        return ['background-color:yellow']*11
    else:
        return ['background-color:lightegreen']*11
df_emp.style.apply(myfun,axis=1)
# Out:
# <style  type="text/css" >
#     #T_d64a0df6_85b4_11eb_b9d6_b0c090b41c34row0_col0 {
#             background-color: yellow;
#         }    #T_d64a0df6_85b4_11eb_b9d6_b0c090b41c34row0_col1 {
#             background-color: yellow;
#         }    #T_d64a0df6_85b4_11eb_b9d6_b0c090b41c34row0_col2 {
#             background-color: yellow;
#         }    #T_d64a0df6_85b4_11eb_b9d6_b0c090b41c34row0_col3 {
#             background-color: yellow;
#         }    #T_d64a0df6_85b4_11eb_b9d6_b0c090b41c34row0_col4 {
#             background-color: yellow;
#         }    #T_d64a0df6_85b4_11eb_b9d6_b0c090b41c34row0_col5 {
#             background-color: yellow;
#         }    #T_d64a0df6_85b4_11eb_b9d6_b0c090b41c34row0_col6 {
#             background-color: yellow;
#         }    #T_d64a0df6_85b4_11eb_b9d6_b0c090b41c34row0_col7 {
#             background-color: yellow;
#         }    #T_d64a0df6_85b4_11eb_b9d6_b0c090b41c34row0_col8 {
#             background-color: yellow;
# ...

# %%
import seaborn as sns
cm=sns.light_palette("red",as_cmap=True)
df_emp.style.background_gradient(cmap='viridis')
# Out:
# <style  type="text/css" >
#     #T_2929e19e_85b4_11eb_883b_b0c090b41c34row0_col0 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_2929e19e_85b4_11eb_883b_b0c090b41c34row0_col4 {
#             background-color:  #5ec962;
#             color:  #000000;
#         }    #T_2929e19e_85b4_11eb_883b_b0c090b41c34row0_col8 {
#             background-color:  #22a884;
#             color:  #000000;
#         }    #T_2929e19e_85b4_11eb_883b_b0c090b41c34row0_col10 {
#             background-color:  #3fbc73;
#             color:  #000000;
#         }    #T_2929e19e_85b4_11eb_883b_b0c090b41c34row1_col0 {
#             background-color:  #482878;
#             color:  #f1f1f1;
#         }    #T_2929e19e_85b4_11eb_883b_b0c090b41c34row1_col4 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_2929e19e_85b4_11eb_883b_b0c090b41c34row1_col8 {
#             background-color:  #fde725;
#             color:  #000000;
# ...

# %%
df_emp.style.set_properties(**{'color':'black','background-color':'brown'})
# Out:
# <style  type="text/css" >
#     #T_ecbf15b6_85b4_11eb_8a05_b0c090b41c34row0_col0 {
#             color:  black;
#             background-color:  brown;
#         }    #T_ecbf15b6_85b4_11eb_8a05_b0c090b41c34row0_col1 {
#             color:  black;
#             background-color:  brown;
#         }    #T_ecbf15b6_85b4_11eb_8a05_b0c090b41c34row0_col2 {
#             color:  black;
#             background-color:  brown;
#         }    #T_ecbf15b6_85b4_11eb_8a05_b0c090b41c34row0_col3 {
#             color:  black;
#             background-color:  brown;
#         }    #T_ecbf15b6_85b4_11eb_8a05_b0c090b41c34row0_col4 {
#             color:  black;
#             background-color:  brown;
#         }    #T_ecbf15b6_85b4_11eb_8a05_b0c090b41c34row0_col5 {
#             color:  black;
#             background-color:  brown;
#         }    #T_ecbf15b6_85b4_11eb_8a05_b0c090b41c34row0_col6 {
#             color:  black;
#             background-color:  brown;
# ...

# %%
import seaborn as sns
cm=sns.color_palette("coolwarm")
df_emp.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_244844d0_85b7_11eb_ad30_b0c090b41c34row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_244844d0_85b7_11eb_ad30_b0c090b41c34row0_col4 {
#             background-color:  #056faf;
#             color:  #f1f1f1;
#         }    #T_244844d0_85b7_11eb_ad30_b0c090b41c34row0_col8 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_244844d0_85b7_11eb_ad30_b0c090b41c34row0_col10 {
#             background-color:  #1c7fb8;
#             color:  #000000;
#         }    #T_244844d0_85b7_11eb_ad30_b0c090b41c34row1_col0 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_244844d0_85b7_11eb_ad30_b0c090b41c34row1_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_244844d0_85b7_11eb_ad30_b0c090b41c34row1_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
# ...
